# %% [markdown]
# <a href="https://colab.research.google.com/github/maleal2/Hands-On-Artificial-Intelligence-for-IoT/blob/main/DecisionTreeRegression__PowerOutageHomes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing neecessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor

# %%
# Extracting CSV file into new dataframe called: df.
df= pd.read_excel("/content/sample_data/Folds5x2_pp.xlsx", sheet_name='Sheet1')

# %%
# Inspecting dataframe.
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
# Checking basic statistics.
df.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
# Selecting all columns except the last one for "X" , then normalizing the values of X.
X= df.drop(['PE'],axis=1)
scaler = MinMaxScaler()
X_new = scaler.fit_transform(X)
Y = df[['PE']] # Selecting all values under "quality" column.

# %%
X.shape
# Out:
# (9568, 4)

# %%
Y.shape
# Out:
# (9568, 1)

# %%
#label_encoder = LabelEncoder()  # Converting 2D array into 1D array. This is only for converting from categorical values to numerical values.
#y = label_encoder.fit_transform(Y['PE'])

# %%
target_scaler = MinMaxScaler()  # This is used for scaling numerica values into certain ranges, in this case : -1 and 1.
y = target_scaler.fit_transform(Y.values.reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_new, y, test_size=0.4, random_state=333)  # Splitting dataset.

# %%
# Defining the decision tree regressor.
model= DecisionTreeRegressor(max_depth=3)  # Defininf tree regression maker with max depth to 3 . This is for stopping the search up to level 3.
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
y_pre = model.predict(X_test)  # Predictin values for Y.

# %%
print("R2_Score is {:.2f} and MSE {}:".format(r2_score(Y_test,y_pre), mean_squared_error(Y_test,y_pre)))  # Printing R2_score and mean squared errors between predicted value and the expected value.
# Out:
# R2_Score is 0.91 and MSE 0.004748858361843866:
